# %%
import re
import pandas as pd

# %%
print(help(re))
# Out:
# Help on package re:
#
# NAME
#     re - Support for regular expressions (RE).
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/re.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides regular expression matching operations similar to
#     those found in Perl.  It supports both 8-bit and Unicode strings; both
#     the pattern and the strings being processed can contain null bytes and
#     characters outside the US ASCII range.
#
#     Regular expressions can contain both special and ordinary characters.
#     Most ordinary characters, like "A", "a", or "0", are the simplest
#     regular expressions; they simply match themselves.  You can
# ...

# %%
#1 
text='Python Exercises, PHP exercises.'
pattern=(re.sub('[ ,.]',':',text))
print(pattern)
# Out:
# Python:Exercises::PHP:exercises:

# %%
#2
data={'SUMMARY': ['hello ,world!', 'XXXXX test', ' 123four, five:; six...']}
df=pd.DataFrame(data)
df=df['SUMMARY'].str.replace(r'[^ a-z]','',regex= True)
print(df)
# Out:
# 0       hello world
# 1              test
# 2     four five six
# Name: SUMMARY, dtype: object

# %%
#3
str1= "APJ Abdul Kalam was an Indian aerospace scientist also known as the missile1234 Man of India"
pattern=re.compile(r"\w{4}")
matches=pattern.findall(str1)
print(matches)
# Out:
# ['Abdu', 'Kala', 'Indi', 'aero', 'spac', 'scie', 'ntis', 'also', 'know', 'miss', 'ile1', 'Indi']

# %%
#4
str2= "APJ Abdul Kalam was an Indian aerospace scientist also knowm as the missile man of India"
pattern =re.compile(r"\w{3,5}")
matches=pattern.findall(str2)
print(matches)
# Out:
# ['APJ', 'Abdul', 'Kalam', 'was', 'India', 'aeros', 'pace', 'scien', 'tist', 'also', 'knowm', 'the', 'missi', 'man', 'India']

# %%
#5
text1= ["example(.com)","hr@fliprobo(.com)","github(.com)","Hello(Data Science World)","Data(Scientist)"]
pattern=re.compile(r'\([^)]+\)')
for t in text1:
 print(pattern.sub('',t))
# Out:
# example
# hr@fliprobo
# github
# Hello
# Data

# %%
#6
file=open('parenthesis.txt','w')
file.writelines(["example(.com)","hr@fliprobo(.com)","github(.com)","Hello(Data Science World)","Data(Scientist)"])
file.close()

# %%
file=open('parenthesis.txt','r')
x=file.read()
pattern=re.sub(r"\([^)]+\)",',',x)
print(pattern)
# Out:
# example,hr@fliprobo,github,Hello,Data,

# %%
#7
text3="ImportanceOfRegularExpressionsInPython"
x=re.split('(?<=.)(?=[A-Z])',text3)
print(x)
# Out:
# ['Importance', 'Of', 'Regular', 'Expressions', 'In', 'Python']

# %%
#8
text4="RegularExpressions1IsAn2ImportantTopic3InPython"
space=re.sub('(\d+)', r' \1',text4)
print(space)
# Out:
# RegularExpressions 1IsAn 2ImportantTopic 3InPython

# %%
#9
text5="RegularExpressions1IsAn2ImportantTopic3InPython"
pattern= re.sub('(\d+(\.\d+)?)',r' \1 ',text5)
print(pattern)
# Out:
# RegularExpressions 1 IsAn 2 ImportantTopic 3 InPython

# %%
#10
url="https://raw.githubusercontent.com/dsrscientist/DSdata/master/happiness_score_dataset.csv"
df=pd.read_csv(url)

# %%
print(df)
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df["first_five_letters"]=df["Country"].str[:6]
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#11
string="2023 Virat is a_ cricket player who was born on November 5 #@77 &*"
match=re.match(r'^\w.+',string)
print(match)
# Out:
# <re.Match object; span=(0, 66), match='2023 Virat is a_ cricket player who was born on N>

# %%
#12
string1="566 bananas are there in a box and 600 apples in the other boxes"
pattern=re.search(r'^\b\d',string1)
print(pattern)
# Out:
# <re.Match object; span=(0, 1), match='5'>

# %%
#13
IP=input('enter a string ')
clean_IP= re.sub(r'\b0+(\d)',r'\1',IP)
print(clean_IP)
# Out:
# enter a string 087890--889-98u
# 87890--889-98u

# %%
#14
file1=open('date.txt','w')
file1.writelines(["On August 15th 1947 that India was decleared independent from British colonialism,and the reins of control were handed over to the leaders of the country"])
file1.close()

# %%
file1=open('date.txt','r')
x=file1.read()
date=re.findall(r'\w+ \d{1,2}(?:th) \d{4}',x)
print(date)
# Out:
# ['August 15th 1947']

# %%
#15
sample_text='The quick brown fox jumps over the lazy dog.'
pattern=re.search('cat|dog|fox|horse',sample_text)
print(pattern)
# Out:
# <re.Match object; span=(16, 19), match='fox'>

# %%
#16
sample_text1='The quick brown fox jumps over the lazy dog.'
pattern=re.search(r"\bfox\b",sample_text1)
print(pattern)
print(pattern.group())
# Out:
# <re.Match object; span=(16, 19), match='fox'>
# fox

# %%
#17
sample3="Python exercises, PHP exercises, C# exercises"
substring='exercises'
result= re.findall(substring,sample3)
print(result)
# Out:
# ['exercises', 'exercises', 'exercises']

# %%
#18
string="Python exercises, PHP exercises, C# exercises"
substring='exercises'
r=re.finditer(substring,string)
for match in r:
  print(substring,match.span())
# Out:
# exercises (7, 16)
# exercises (22, 31)
# exercises (36, 45)

# %%
#19
date="2024-01-31"
new=re.sub(r'(\d{4})-(\d{2})-(\d{2})',r'\3-\2-\1',date)
print(new)
# Out:
# 31-01-2024

# %%
#20
number='01.12 0132.123 2.31875 145.8 3.01 27.25 0.25'
pattern=re.compile(r'\b\d+\.\d{1,2}\b')
pattern.findall(number)
# Out:
# ['01.12', '145.8', '3.01', '27.25', '0.25']

# %%
#21
text= 'Virat made 345 runs in his cricket match'
for p in re.finditer('\d+',text):
    print(p.group(0))
    print('position:',p.start())
# Out:
# 345
# position: 11

# %%
#22
marks="My marks in each semester are: 947, 896, 926, 524, 734, 950, 642"
number=re.findall('\d+',marks)
print(max(number))
# Out:
# 950

# %%
#23
space='RegularExpressionIsAnImportantTopicInPython'
result=re.sub(r'([A-Z][a-z]+)', r' \1',space)
print(result)
# Out:
#  Regular Expression Is An Important Topic In Python

# %%
#24
sequence=' Abdul Kalam was the scientist of India'
pattern=re.findall(r'[A-Z][a-z]+',sequence)
print(pattern)
# Out:
# ['Abdul', 'Kalam', 'India']

# %%
#25
text="Hello hello world world"
pattern=re.sub(r'\b(\w+)( \1\b)+',r'\1',text)
print(pattern)
# Out:
# Hello hello world

# %%
#26
p=input('enter alphanumeric character ')
result=('[a-zA-Z0-9]$')
if(re.search(result,p)):
 print('Accept')
else:
    print('Reject')
# Out:
# enter alphanumeric character  guhb677
# Accept

# %%
#27
x="""RT@Kapil_Kusik: #Doltiwal I mean #xyzabc is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo"""
pattern=re.findall('#[a-zA-Z]+',x)
print(pattern)
# Out:
# ['#Doltiwal', '#xyzabc', '#Demonetization']

# %%
#28
text= "@jags123456 Bharat band on28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who are protesting #demonetization are all different party leaders"
result=re.sub(r'<U\+\w+>','',text)
print(result)
# Out:
# @jags123456 Bharat band on28??<ed><ed>Those who are protesting #demonetization are all different party leaders

# %%
#29
file2=open("text.txt",'w')
file2.writelines('Ron was born on 12-09-1992 and he was admitted to school 15-12-1999')
file2.close()

# %%
file2=open("text.txt",'r')
x=file2.read()
date= re.findall(r'\d{2}-\d{2}-\d{4}',x)
print(date)
# Out:
# ['12-09-1992', '15-12-1999']

# %%
#30
ex="The following example creates an Arrylist with a capicity of 50 elements. 4 elements are then added to the Arrylist and the Arrylist is trimmed accordingly"
pattern=re.compile(r'\W*\b\w{2,4}\b')
print(pattern.sub('',ex))
# Out:
#  following example creates Arrylist a capicity elements. 4 elements added Arrylist Arrylist trimmed accordingly
