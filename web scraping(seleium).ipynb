# %%
# !pip install selenium
# !pip install webdriver_manager

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import time

# %%
driver= webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
driver.get('https://www.shine.com/job-search/data-analyst-jobs-in-bangalore?q=data-analyst&loc=Bangalore')

# %%
designation= driver.find_element(By.CLASS_NAME,"input")
designation.send_keys('Data Analyst')

# %%
location= driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div[2]/div[2]/div[1]/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Bangalore')

# %%
Search=driver.find_element(By.CLASS_NAME,'searchForm_btnWrap_advance__VYBHN')
Search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags= driver.find_elements(By.XPATH,'//h2[@itemprop="name"]/a')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
    
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
    
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)
    
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company name':company_name,'Experience':experience_required})
df
# Out:
#                                                 Title        Location  \
# 0   Data Analyst , Senior Data Analyst , Data Anal...   Bangalore\n+8
# 1                               Clinical Data Analyst   Bangalore\n+6
# 2                                        Data Analyst   Bangalore\n+9
# 3                             Hiring For Data Analyst  Bangalore\n+12
# 4                                        Data Analyst       Bangalore
# 5                                   Lead Data Analyst       Bangalore
# 6                                        Data Analyst   Bangalore\n+3
# 7                                        Data Science       Bangalore
# 8   Senior Consultant/Principal - Business Consult...       Bangalore
# 9                            Vacancy For Data Analyst  Bangalore\n+14
# 10                           Technical Data Architect       Bangalore
# 11                                  Gen AI- Developer       Bangalore
# ...

# %%
driver.get('https://www.naukri.com/')

# %%
designation1=driver.find_element(By.CLASS_NAME,'suggestor-input')
designation1.send_keys('Data Scientist')

# %%
location1=driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
location1.send_keys('Bangalore')

# %%
search1=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search1.click()

# %%
Job_title=[]
Job_location=[]
Company_name=[]
Experience_require=[]

# %%
 title_=driver.find_elements(By.XPATH,'//div[@class=" row1"]')
for i in title_:
    title=i.text
    Job_title.append(title)
    
    
    
location_=driver.find_elements(By.XPATH,'//span[@class="locWdth"]')
for i in location_:
    location=i.text
    Job_location.append(location)
    
    
company_=driver.find_elements(By.XPATH,'//a[@class=" comp-name mw-25"]')
for i in company_:
    company=i.text
    Company_name.append(company)
    
    
experience_=driver.find_elements(By.XPATH,'//span[@class="expwdth"]')
for i in experience_:
    experience=i.text
    Experience_require.append(experience)

# %%
print(len(Job_title),len(Job_location),len(Company_name),len(Experience_require))
# Out:
# 100 80 76 80

# %%
dg=pd.DataFrame({'Job Title':Job_title,'Job Location':Job_location,'Company name':Company_name,'Experience Require':Experience_require})
dg

# %%
driver.get('https://www.flipkart.com/')

# %%
designation2=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
designation2.send_keys('sunglasses men')

# %%
Search1=driver.find_element(By.CLASS_NAME,'_2iLD__')
Search1.click()

# %%
Brand=[]
ProductDescription=[]
Price=[]

# %%
start=0
end=3
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand:
        Brand.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
len(Brand)
# Out:
# 600

# %%
Brand
# Out:
# ['VINCENT CHASE',
#  'VINCENT CHASE',
#  'SRPM',
#  'Fastrack',
#  'Elligator',
#  'Fastrack',
#  'Aarna Fashion',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Elligator',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'Elligator',
#  'Rozti',
#  'ROADWAY',
#  'Elligator',
#  'VINCENT CHASE',
#  'Eyenaks',
#  'Aarna Fashion',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'Rich Club',
#  'Elligator',
#  'Fastrack',
#  'Fastrack',
#  'Singco India',
#  'VINCENT CHASE',
#  'Capitalpoint',
#  'PIRASO',
#  'VINCENT CHASE',
#  'Eyewearlabs',
#  'PIRASO',
#  'Aarna Fashion',
#  'PIRASO',
#  'PIRASO',
#  'ROYAL SON',
#  'VINCENT CHASE',
#  'IDEE',
#  'Elligator',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'Elligator',
#  'Fastrack',
#  'PIRASO',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'SRPM',
#  'aferelle',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'PIRASO',
#  'PIRASO',
#  'ROADWAY',
#  'Fastrack',
#  'Eyenaks',
#  'VINCENT CHASE',
#  'PIRASO',
#  'RBGIIT',
# ...

# %%
start=0
end=3
for page in range(start,end):
    product=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product:
        ProductDescription.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
len(ProductDescription)
# Out:
# 113

# %%
ProductDescription
# Out:
# ['by Lenskart Polarized, UV Protection Rectangular Sungla...',
#  'by Lenskart Polarized, UV Protection Aviator Sunglasses...',
#  'UV Protection, Mirrored Wayfarer Sunglasses (52)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (58)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'by Lenskart UV Protection Clubmaster Sunglasses (55)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (53)',
#  'by Lenskart UV Protection Wayfarer Sunglasses (59)',
#  'by Lenskart Polarized, UV Protection Round Sunglasses (...',
#  'UV Protection Wayfarer Sunglasses (50)',
#  'UV Protection Sports Sunglasses (50)',
#  'UV Protection Wayfarer, Sports, Spectacle , Retro Squar...',
#  'UV Protection Cat-eye, Retro Square, Oval, Round Sungla...',
#  'by Lenskart Polarized, UV Protection Round Sunglasses (...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
# ...

# %%
start=0
end=3
for page in range(start,end):
    price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price:
        Price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
len(Price)
# Out:
# 120

# %%
Price
# Out:
# ['₹499',
#  '₹1,799',
#  '₹297',
#  '₹503',
#  '₹209',
#  '₹399',
#  '₹565',
#  '₹1,799',
#  '₹290',
#  '₹232',
#  '₹1,277',
#  '₹854',
#  '₹169',
#  '₹296',
#  '₹699',
#  '₹169',
#  '₹560',
#  '₹594',
#  '₹620',
#  '₹709',
#  '₹565',
#  '₹809',
#  '₹643',
#  '₹749',
#  '₹399',
#  '₹699',
#  '₹752',
#  '₹542',
#  '₹269',
#  '₹221',
#  '₹560',
#  '₹1,049',
#  '₹449',
#  '₹579',
#  '₹649',
#  '₹513',
#  '₹542',
#  '₹1,709',
#  '₹249',
#  '₹187',
#  '₹649',
#  '₹699',
#  '₹169',
#  '₹169',
#  '₹500',
#  '₹569',
#  '₹284',
#  '₹699',
#  '₹575',
#  '₹169',
#  '₹699',
#  '₹499',
#  '₹169',
#  '₹225',
#  '₹254',
#  '₹149',
#  '₹779',
#  '₹385',
#  '₹247',
#  '₹159',
#  '₹699',
#  '₹399',
#  '₹449',
#  '₹399',
#  '₹769',
#  '₹829',
#  '₹2,199',
#  '₹699',
#  '₹225',
#  '₹210',
#  '₹499',
#  '₹399',
#  '₹699',
#  '₹247',
#  '₹514',
#  '₹159',
#  '₹806',
#  '₹359',
#  '₹297',
#  '₹503',
#  '₹569',
#  '₹580',
#  '₹297',
#  '₹503',
#  '₹209',
#  '₹399',
#  '₹1,799',
#  '₹565',
#  '₹290',
# ...
